# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('funds_train.csv')

# %%
df.head()
# Out:
#                                 fund_id  \
# 0  f2936057-6df5-4757-9dd5-409f11d981e8
# 1  a9f2b3ce-d611-4719-9907-25eb10564f57
# 2  a007bb1b-f8a8-4abf-8429-6e66acb4c2fc
# 3  5be85318-fd20-4875-af01-4544066ca707
# 4  48dbf6e9-8055-40d0-8f1f-c8b3079f224b
#
#                                            fund_name parent_company fund_size  \
# 0        AMG TimesSquare Mid Cap Growth Fund Class Z      AMG Funds    Medium
# 1  Putnam Massachusetts Tax Exempt Income Fund Cl...         Putnam    Medium
# 2                                FundX Upgrader Fund         Fund X     Large
# 3  Invesco Balanced-Risk Retirement 2040 Fund Cla...        Invesco       NaN
# 4                       ICON Long/Short Fund Class A     ICON Funds     Large
#
#    greatstone_return_rating  greatstone_risk_rating  \
# 0                       3.0                     2.0
# 1                       2.0                     3.0
# 2                       4.0                     4.0
# 3                       1.0                     1.0
# 4                       2.0                     3.0
#
#    fund_ratio_net_annual_expense  10_years_return_mean_annual_fund  \
# 0                           0.98                              1.29
# 1                           1.57                              0.31
# 2                           1.89                              1.03
# 3                           1.40                              0.82
# 4                           1.55                              0.93
#
#    10_years_return_fund  3_years_return_mean_annual_fund  ...  \
# 0                 15.49                             1.14  ...
# 1                  3.69                             0.11  ...
# 2                 12.07                             0.94  ...
# 3                  9.91                             0.62  ...
# 4                 10.55                             1.13  ...
#
#    portfolio_tech_allocation  10years_fund_std  \
# 0                      20.47             14.20
# 1                       0.00              4.06
# 2                      28.04             13.75
# 3                       0.00              9.01
# 4                       6.89             14.46
#
#    portfolio_healthcare_allocation  portfolio_others  2010_return_category  \
# 0                            14.60              0.00                 24.61
# 1                             0.00              0.00                  1.08
# 2                            15.71              0.09                 14.83
# 3                             0.00              9.62                 14.37
# 4                            13.31              0.00                 24.61
#
#    years_down  3_years_return_category  5_years_beta_category  \
# 0         3.0                    14.18                   0.01
# 1         4.0                     1.77                   0.01
# 2         4.0                     9.60                   0.02
# 3         2.0                     9.54                   0.01
# 4         3.0                    14.18                   0.01
#
#    2018_return_fund  greatstone_rating
# 0             -4.39                  3
# 1             -0.56                  2
# 2             -3.71                  4
# 3             -8.44                  1
# 4            -16.91                  2
#
# [5 rows x 55 columns]

# %%
test_df  = pd.read_csv('funds_test.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18981 entries, 0 to 18980
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   fund_id                                 18981 non-null  object
#  1   fund_name                               18981 non-null  object
#  2   parent_company                          18981 non-null  object
#  3   fund_size                               17858 non-null  object
#  4   greatstone_return_rating                18980 non-null  float64
#  5   greatstone_risk_rating                  18979 non-null  float64
#  6   fund_ratio_net_annual_expense           18981 non-null  float64
#  7   10_years_return_mean_annual_fund        12464 non-null  float64
#  8   10_years_return_fund                    18896 non-null  float64
#  9   3_years_return_mean_annual_fund         17728 non-null  float64
#  10  fund_return_3years                      18896 non-null  float64
#  11  2012_fund_return                        11364 non-null  float64
#  12  aaa_rating                              18899 non-null  float64
#  13  10_years_beta_category                  18899 non-null  float64
#  14  3_years_return_mean_annual_category     18899 non-null  float64
#  15  5_years_alpha_fund                      16051 non-null  float64
#  16  10_years_alpha_fund                     12464 non-null  float64
#  17  10yrs_sharpe_ratio_fund                 12464 non-null  float64
#  18  3_years_alpha_fund                      17728 non-null  float64
#  19  cash_percent_of_portfolio               18899 non-null  float64
#  20  10_years_beta_fund                      12464 non-null  float64
#  21  10_years_return_mean_annual_category    18899 non-null  float64
#  22  5yrs_sharpe_ratio_fund                  16051 non-null  float64
#  23  3yrs_sharpe_ratio_fund                  17728 non-null  float64
#  24  2016_return_fund                        16006 non-null  float64
#  25  2010_return_fund                        9642 non-null   float64
#  26  yield                                   18896 non-null  float64
#  27  portfolio_energy_allocation             18899 non-null  float64
#  28  aa_rating                               18899 non-null  float64
#  29  portfolio_property_allocation           18899 non-null  float64
#  30  5_years_return_mean_annual_fund         16051 non-null  float64
#  31  5_years_return_fund                     18896 non-null  float64
#  32  portfolio_financial_services            18899 non-null  float64
#  33  stock_percent_of_portfolio              18899 non-null  float64
#  34  b_rating                                18899 non-null  float64
#  35  portfolio_cyclical_consumer_allocation  18899 non-null  float64
#  36  2016_return_category                    16633 non-null  float64
#  37  below_b_rating                          18899 non-null  float64
#  38  2017_return_fund                        17050 non-null  float64
#  39  return_ytd                              18910 non-null  float64
#  40  ytd_return_fund                         18896 non-null  float64
#  41  fund_return_3months                     18896 non-null  float64
#  42  2014_return_fund                        13502 non-null  float64
#  43  pb_ratio                                18899 non-null  float64
#  44  1_year_return_fund                      18896 non-null  float64
#  45  portfolio_tech_allocation               18899 non-null  float64
#  46  10years_fund_std                        12464 non-null  float64
#  47  portfolio_healthcare_allocation         18899 non-null  float64
#  48  portfolio_others                        18899 non-null  float64
#  49  2010_return_category                    10224 non-null  float64
#  50  years_down                              17743 non-null  float64
#  51  3_years_return_category                 18896 non-null  float64
#  52  5_years_beta_category                   18899 non-null  float64
#  53  2018_return_fund                        18274 non-null  float64
#  54  greatstone_rating                       18981 non-null  int64
# dtypes: float64(50), int64(1), object(4)
# memory usage: 8.0+ MB

# %%
df.isnull().sum()
# Out:
# fund_id                                      0
# fund_name                                    0
# parent_company                               0
# fund_size                                 1123
# greatstone_return_rating                     1
# greatstone_risk_rating                       2
# fund_ratio_net_annual_expense                0
# 10_years_return_mean_annual_fund          6517
# 10_years_return_fund                        85
# 3_years_return_mean_annual_fund           1253
# fund_return_3years                          85
# 2012_fund_return                          7617
# aaa_rating                                  82
# 10_years_beta_category                      82
# 3_years_return_mean_annual_category         82
# 5_years_alpha_fund                        2930
# 10_years_alpha_fund                       6517
# 10yrs_sharpe_ratio_fund                   6517
# 3_years_alpha_fund                        1253
# cash_percent_of_portfolio                   82
# 10_years_beta_fund                        6517
# 10_years_return_mean_annual_category        82
# 5yrs_sharpe_ratio_fund                    2930
# 3yrs_sharpe_ratio_fund                    1253
# 2016_return_fund                          2975
# 2010_return_fund                          9339
# yield                                       85
# portfolio_energy_allocation                 82
# aa_rating                                   82
# portfolio_property_allocation               82
# 5_years_return_mean_annual_fund           2930
# 5_years_return_fund                         85
# portfolio_financial_services                82
# stock_percent_of_portfolio                  82
# b_rating                                    82
# portfolio_cyclical_consumer_allocation      82
# 2016_return_category                      2348
# below_b_rating                              82
# 2017_return_fund                          1931
# return_ytd                                  71
# ytd_return_fund                             85
# fund_return_3months                         85
# 2014_return_fund                          5479
# pb_ratio                                    82
# 1_year_return_fund                          85
# portfolio_tech_allocation                   82
# 10years_fund_std                          6517
# portfolio_healthcare_allocation             82
# portfolio_others                            82
# 2010_return_category                      8757
# years_down                                1238
# 3_years_return_category                     85
# 5_years_beta_category                       82
# 2018_return_fund                           707
# greatstone_rating                            0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# fund_id                                      0
# fund_name                                    0
# parent_company                               0
# fund_size                                  379
# greatstone_return_rating                     0
# greatstone_risk_rating                       0
# fund_ratio_net_annual_expense                0
# 10_years_return_mean_annual_fund          2169
# 10_years_return_fund                        32
# 3_years_return_mean_annual_fund            416
# fund_return_3years                          32
# 2012_fund_return                          2493
# aaa_rating                                  33
# 10_years_beta_category                      26
# 3_years_return_mean_annual_category         26
# 5_years_alpha_fund                         964
# 10_years_alpha_fund                       2169
# 10yrs_sharpe_ratio_fund                   2169
# 3_years_alpha_fund                         416
# cash_percent_of_portfolio                   33
# 10_years_beta_fund                        2169
# 10_years_return_mean_annual_category        26
# 5yrs_sharpe_ratio_fund                     964
# 3yrs_sharpe_ratio_fund                     416
# 2016_return_fund                          1005
# 2010_return_fund                          3081
# yield                                       44
# portfolio_energy_allocation                 33
# aa_rating                                   33
# portfolio_property_allocation               33
# 5_years_return_mean_annual_fund            964
# 5_years_return_fund                         32
# portfolio_financial_services                33
# stock_percent_of_portfolio                  33
# b_rating                                    33
# portfolio_cyclical_consumer_allocation      33
# 2016_return_category                       785
# below_b_rating                              33
# 2017_return_fund                           655
# return_ytd                                  39
# ytd_return_fund                             32
# fund_return_3months                         32
# 2014_return_fund                          1819
# pb_ratio                                    33
# 1_year_return_fund                          32
# portfolio_tech_allocation                   33
# 10years_fund_std                          2169
# portfolio_healthcare_allocation             33
# portfolio_others                            33
# 2010_return_category                      2922
# years_down                                 420
# 3_years_return_category                     32
# 5_years_beta_category                       26
# 2018_return_fund                           247
# dtype: int64

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)
test_df = test_df.replace(r'^\s*$', np.nan, regex=True)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
df['parent_company']=label_encoder.fit_transform(df['parent_company']) 
df['fund_size']=df.fund_size.map({'Small':1,'Medium':2,'Large':3})
test_df['parent_company']=label_encoder.fit_transform(test_df['parent_company']) 
test_df['fund_size']=test_df.fund_size.map({'Small':1,'Medium':2,'Large':3})

# %%
df.describe()
# Out:
#        parent_company     fund_size  greatstone_return_rating  \
# count    18981.000000  17858.000000              18980.000000
# mean       358.658922      2.461922                  2.825711
# std        195.917005      0.728872                  1.283828
# min          0.000000      1.000000                  0.000000
# 25%        224.000000      2.000000                  2.000000
# 50%        356.000000      3.000000                  3.000000
# 75%        506.000000      3.000000                  4.000000
# max        708.000000      3.000000                  5.000000
#
#        greatstone_risk_rating  fund_ratio_net_annual_expense  \
# count            18979.000000                   18981.000000
# mean                 2.849254                       1.123178
# std                  1.304792                       0.609661
# min                  0.000000                       0.000000
# 25%                  2.000000                       0.720000
# 50%                  3.000000                       1.010000
# 75%                  4.000000                       1.440000
# max                  5.000000                      15.170000
#
#        10_years_return_mean_annual_fund  10_years_return_fund  \
# count                      12464.000000          18896.000000
# mean                           0.856763              6.606131
# std                            0.456088              6.509155
# min                           -3.640000            -38.560000
# 25%                            0.520000              0.000000
# 50%                            0.890000              5.880000
# 75%                            1.200000             12.320000
# max                            3.110000             37.920000
#
#        3_years_return_mean_annual_fund  fund_return_3years  2012_fund_return  \
# count                     17728.000000        18896.000000      11364.000000
# mean                          0.636826            7.005191         12.899940
# std                           0.433877            5.434615          7.114878
# min                          -3.190000          -35.330000        -43.900000
# 25%                           0.330000            2.810000          8.870000
# 50%                           0.620000            6.830000         13.480000
# 75%                           0.890000           10.210000         16.860000
# max                           2.980000           38.420000         81.660000
#
#        ...  portfolio_tech_allocation  10years_fund_std  \
# count  ...               18899.000000      12464.000000
# mean   ...                  12.736702         11.401625
# std    ...                  12.540686          5.946367
# min    ...                   0.000000          0.200000
# 25%    ...                   0.000000          6.110000
# 50%    ...                  12.810000         12.720000
# 75%    ...                  19.600000         15.610000
# max    ...                 100.000000         52.290000
#
#        portfolio_healthcare_allocation  portfolio_others  \
# count                     18899.000000      18899.000000
# mean                          8.526779          1.044660
# std                           9.649782          4.307163
# min                           0.000000          0.000000
# 25%                           0.000000          0.000000
# 50%                           9.360000          0.000000
# 75%                          13.590000          0.280000
# max                         100.000000         98.840000
#
#        2010_return_category    years_down  3_years_return_category  \
# count          10224.000000  17743.000000             18896.000000
# mean              13.125552      3.241616                 7.450142
# std                7.627948      2.333694                 4.441019
# min              -28.950000      1.000000               -19.790000
# 25%                8.600000      1.000000                 4.360000
# 50%               13.660000      3.000000                 7.440000
# 75%               15.530000      4.000000                10.010000
# max               41.560000     28.000000                21.780000
#
#        5_years_beta_category  2018_return_fund  greatstone_rating
# count           18899.000000      18274.000000       18981.000000
# mean                0.008620         -6.702591           2.839945
# std                 0.004017          6.682707           1.277464
# min                -0.020000        -59.100000           0.000000
# 25%                 0.010000        -10.590000           2.000000
# 50%                 0.010000         -5.810000           3.000000
# 75%                 0.010000         -1.600000           4.000000
# max                 0.030000         39.470000           5.000000
#
# [8 rows x 53 columns]

# %%
df.fillna(df.median(), inplace=True)
test_df.fillna(test_df.median(), inplace=True)

# %%
X_train = df[['greatstone_return_rating','greatstone_risk_rating','3_years_return_mean_annual_fund','portfolio_property_allocation','5_years_return_mean_annual_fund','stock_percent_of_portfolio','portfolio_cyclical_consumer_allocation','2017_return_fund','1_year_return_fund']]
X_test = test_df[['greatstone_return_rating','greatstone_risk_rating','3_years_return_mean_annual_fund','portfolio_property_allocation','5_years_return_mean_annual_fund','stock_percent_of_portfolio','portfolio_cyclical_consumer_allocation','2017_return_fund','1_year_return_fund']]

# %%
X_train.plot.hist( subplots = True, grid = True,figsize = (40,40))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002A1AE368408>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A131714B48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1AE40A1C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1B0D39848>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1AE4AD448>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1A5C72088>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1A5CA2C08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1A5CD9808>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002A1A5CE1688>],
#       dtype=object)

# %%
corr=X_train.corr() 
plt.figure(figsize=(20, 20))
sns.heatmap(corr,  vmax=1.0, vmin=-1.0, annot = True)

# %%
y_train =df['greatstone_rating']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
test_df['greatstone_rating'] = y_pred
solution = test_df[['fund_id', 'greatstone_rating']] 
solution.to_csv ('solution.csv', index = False, header=True)

# %%
from sklearn.ensemble import AdaBoostClassifier
abcl = AdaBoostClassifier()
abcl.fit(X_train, y_train)
y_pred = abcl.predict(X_test)

# %%
test_df['greatstone_rating'] = y_pred
solution = test_df[['fund_id', 'greatstone_rating']] 
solution.to_csv ('solution_a.csv', index = False, header=True)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_pred = gb.predict(X_test)

# %%
test_df['greatstone_rating'] = y_pred
solution = test_df[['fund_id', 'greatstone_rating']] 
solution.to_csv ('solution_b.csv', index = False, header=True)

# %%
from sklearn.ensemble import BaggingClassifier
bgcl = BaggingClassifier()
bgcl.fit(X_train, y_train)
y_pred = bgcl.predict(X_test)

# %%
test_df['greatstone_rating'] = y_pred
solution = test_df[['fund_id', 'greatstone_rating']] 
solution.to_csv ('solution_c.csv', index = False, header=True)
